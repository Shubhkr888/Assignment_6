# %% [markdown]
# Question 1
#
# Escape character is a backslash followed by character we want to insert.

# %%
#print("My name is "Shubham"")
print("My name is \"Shubham\"")
print("My name is \nShubham")
print("My name is \tShubham")
# Out:
# My name is "Shubham"
# My name is
# Shubham
# My name is 	Shubham

# %% [markdown]
# Question 2
#
#
# n stands for new line and t stands for tab

# %%
#Question 3
print("My name is \"Shubham\"")
# Out:
# My name is "Shubham"

# %% [markdown]
# Question 4
#
# Because the complete string starts and end with double quotes.

# %% [markdown]
# Question 5
#
# Multiple line strings can used triple quotes instead of \n character

# %% [markdown]
# Question 6
#
# e
#
# Hello
#
# Hello
#
# lo, world!

# %%
Question 7

HELLO


True

hello

# %%
#Question 8
x ="Remember remember the fifth of July".split()
y = '-'.join("There can only one".split())
print(x)
print(y)

z = "My name is shubham".split()
z1 = '-'.join("My name is shubham".split())
print(z)
print(z1)
# Out:
# ['Remember', 'remember', 'the', 'fifth', 'of', 'July']
# There-can-only-one
# ['My', 'name', 'is', 'shubham']
# My-name-is-shubham

# %%
#Question 9
x = "My name is Shubham"
print(x.center(100,'5'))
y = "My name is Shubham"
print(y.ljust(100))
z = "My name is Shubham"
print(z.rjust(100))
# Out:
# 55555555555555555555555555555555555555555My name is Shubham55555555555555555555555555555555555555555
# My name is Shubham
#                                                                                   My name is Shubham

# %%
#Question 10
x = "  My name is Shubham   "
print(x)
print(x.lstrip().rstrip())
# Out:
#   My name is Shubham
# My name is Shubham
